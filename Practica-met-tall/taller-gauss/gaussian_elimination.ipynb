# %% [markdown]
# # Eliminación Gaussiana con sustitución hacia atrás

# %%
# %load_ext autoreload

# %%
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[2.,1,-1,1,-3,7], [1,0,2,-1,1,2], [0,-2,-1,1,-1,-5], [3,1,-4,0,5,6], [1,-1,-1,-1,-1,3]]

eliminacion_gaussiana(Ab)
# Out:
# [12-25 18:56:23][INFO] 2025-12-25 18:56:23.661311
# [12-25 18:56:23][INFO]
# [[ 2.   1.  -1.   1.  -3.   7. ]
#  [ 0.  -0.5  2.5 -1.5  2.5 -1.5]
#  [ 0.  -2.  -1.   1.  -1.  -5. ]
#  [ 0.  -0.5 -2.5 -1.5  9.5 -4.5]
#  [ 0.  -1.5 -0.5 -1.5  0.5 -0.5]]
# [12-25 18:56:23][INFO]
# [[  2.    1.   -1.    1.   -3.    7. ]
#  [  0.   -0.5   2.5  -1.5   2.5  -1.5]
#  [  0.    0.  -11.    7.  -11.    1. ]
#  [  0.    0.   -5.    0.    7.   -3. ]
#  [  0.    0.   -8.    3.   -7.    4. ]]
# [12-25 18:56:23][INFO]
# [[  2.           1.          -1.           1.          -3.
#     7.        ]
#  [  0.          -0.5          2.5         -1.5          2.5
#    -1.5       ]
#  [  0.           0.         -11.           7.         -11.
#     1.        ]
#  [  0.           0.           0.          -3.18181818  12.
#    -3.45454545]
#  [  0.           0.           0.          -2.09090909   1.
#     3.27272727]]
# [12-25 18:56:23][INFO]
# [[  2.           1.          -1.           1.          -3.
#     7.        ]
#  [  0.          -0.5          2.5         -1.5          2.5
#    -1.5       ]
#  [  0.           0.         -11.           7.         -11.
#     1.        ]
#  [  0.           0.           0.          -3.18181818  12.
#    -3.45454545]
#  [  0.           0.           0.           0.          -6.88571429
#     5.54285714]]
# Solución: [ 1.90871369  2.19087137 -0.52697095 -1.95020747 -0.80497925]
# Sumas realizadas: 10
# Restas realizadas: 54
# Multiplicaciones realizadas: 60
# Divisiones realizadas: 15
# Intercambios de filas: 0
# array([ 1.90871369,  2.19087137, -0.52697095, -1.95020747, -0.80497925])

# %%
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, -1, 2, -1, -8], [2, -2, 3, -3, -20], [1, 1, 1, 0, -2], [1, -1, 4, 3, 4]]

eliminacion_gaussiana(Ab)
# Out:
# [12-25 18:57:22][INFO]
# [[ 1. -1.  2. -1. -8.]
#  [ 0.  0. -1. -1. -4.]
#  [ 0.  2. -1.  1.  6.]
#  [ 0.  0.  2.  4. 12.]]
# [12-25 18:57:22][INFO]
# [[ 1. -1.  2. -1. -8.]
#  [ 0.  2. -1.  1.  6.]
#  [ 0.  0. -1. -1. -4.]
#  [ 0.  0.  2.  4. 12.]]
# [12-25 18:57:22][INFO]
# [[ 1. -1.  2. -1. -8.]
#  [ 0.  2. -1.  1.  6.]
#  [ 0.  0. -1. -1. -4.]
#  [ 0.  0.  0.  2.  4.]]
# Solución: [-7  3  2  2]
# Sumas realizadas: 6
# Restas realizadas: 29
# Multiplicaciones realizadas: 32
# Divisiones realizadas: 10
# Intercambios de filas: 1
# array([-7.,  3.,  2.,  2.])

# %% [markdown]
# # Soluciones infinitas
# El siguiente sistema de ecuaciones tiene soluciones infinitas:
#
# |   |   |   |   |
# |---|---|---|---|
# | 1 | 1 | 1 | 4 |
# | 2 | 2 | 1 | 6 |
# | 1 | 1 | 2 | 6 |

# %%
# %load_ext autoreload
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, 1, 1, 4], [2, 2, 1, 6], [1, 1, 2, 6]]

eliminacion_gaussiana(Ab)
# Out:
# [12-22 15:28:36][INFO]
# [[ 1  1  1  4]
#  [ 0  0 -1 -2]
#  [ 0  0  1  2]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 7
#       3 from src import eliminacion_gaussiana
#       5 Ab = [[1, 1, 1, 4], [2, 2, 1, 6], [1, 1, 2, 6]]
# ----> 7 eliminacion_gaussiana(Ab)
#
# File c:\Users\Laboratorio IA\OneDrive\doctorado\profesor\talleres\taller gauss\src\linear_sist_methods.py:65, in eliminacion_gaussiana(A)
#      61         p = pi
#      63 if p is None:
#      64     # no pivot found.
# ---> 65     raise ValueError("No existe solución única.")
#      67 if p != i:
#      68     # swap rows
#      69     logging.debug(f"Intercambiando filas {i} y {p}")
#
# ValueError: No existe solución única.

# %% [markdown]
# # Sin solución
# El siguiente sistema de ecuaciones no tiene solución:
#
# |   |   |   |   |
# |---|---|---|---|
# | 1 | 1 | 1 | 4 |
# | 2 | 2 | 1 | 4 |
# | 1 | 1 | 2 | 6 |

# %%
# %load_ext autoreload
# %autoreload 2
from src import eliminacion_gaussiana

Ab = [[1, 1, 1, 4], [2, 2, 1, 4], [1, 1, 2, 6]]

eliminacion_gaussiana(Ab)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       3 from src import eliminacion_gaussiana
#       5 A = [[1, 1, 1, 4], [2, 2, 1, 4], [1, 1, 2, 6]]
# ----> 7 eliminacion_gaussiana(A)
#
# File c:\Users\Laboratorio IA\OneDrive\doctorado\profesor\2024 - A\Métodos numéricos\clases\python\src\gaussian_elimination.py:65, in eliminacion_gaussiana(A)
#      61         p = pi
#      63 if p is None:
#      64     # no pivot found.
# ---> 65     raise ValueError("No existe solución única.")
#      67 if p != i:
#      68     # swap rows
#      69     _aux = A[i, :].copy()
#
# ValueError: No existe solución única.
